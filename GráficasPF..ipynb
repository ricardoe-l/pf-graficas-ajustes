# %% [markdown]
# Circuito RLC

# %% [markdown]
# Ajuste de gráficas para el circuito en serie con resistencia de 10 ohms, 100 microfarads y sin barra inductora

# %% [markdown]
# 100 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 120 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 140 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 160 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 170 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 175 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 180 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 200 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 220 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 240 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 260 Hz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora se muestran los ajustes para la misma configuración del circuito pero con barra inductora de acero.

# %% [markdown]
# 70 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 60 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 50 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 40 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 30 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 90 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 100 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 110 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 120 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 130 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora, para el experimento adicional se hace una configuración de 10 Ohms, 330 microfarads y sin presencia de barra inductora, los ajustes son los siguientes:

# %% [markdown]
# 20 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 40 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 60 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 80 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 733 rad/S
# ![image.png](attachment:image.png)

# %% [markdown]
# 100 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 140 Hz
# ![image.png](attachment:image.png)

# %% [markdown]
# 972 rad/s
# ![image.png](attachment:image.png)
